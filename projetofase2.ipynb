# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('rotas_saude_mulher.db')

# O Python lê o Banco de Dados e transforma EXATAMENTE no mesmo DataFrame
df_pacientes = pd.read_sql_query("SELECT * FROM pacientes WHERE status = 'pendente'", conn)

# A partir daqui, nada muda! O código do seu professor vai aceitar os dados normalmente
rotas = rodar_algoritmo_genetico(df_pacientes)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import sqlite3
#       4 conn = sqlite3.connect('rotas_saude_mulher.db')
#
# ModuleNotFoundError: No module named 'pandas'
